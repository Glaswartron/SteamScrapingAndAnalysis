# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
games = pd.read_csv("F:\Projekte\DataScience\SteamScraping\SteamSysReqs.csv", encoding='utf-16')

# %%
games
# Out:
#                                     Name  Release date Genre 1       Genre 2  \
# 0      Call of Duty®: Modern Warfare® II  27 Oct, 2022  Action           NaN
# 1             Warhammer 40,000: Darktide  30 Nov, 2022  Action     Adventure
# 2                Need for Speed™ Unbound   1 Dec, 2022  Action        Racing
# 3                 The Callisto Protocol™   1 Dec, 2022  Action     Adventure
# 4                               Lost Ark  11 Feb, 2022  Action     Adventure
# ..                                   ...           ...     ...           ...
# 529                          Sniper Fury  13 Jun, 2017  Action  Free to Play
# 530                    Company of Heroes  11 Sep, 2006  Action      Strategy
# 531                   Assassin's Creed 2   4 Mar, 2010  Action     Adventure
# 532  TramSim Vienna - The Tram Simulator  29 Oct, 2020  Casual    Simulation
# 533           Bendy and the Dark Revival  15 Nov, 2022  Action     Adventure
#
#      Rating                                             Min OS  \
# 0       6.0                 Windows® 10 64 Bit (latest update)
# 1       6.0          Windows 10 (64 bit) / Windows 11 (64 bit)
# 2       7.0                                  Windows 10 64-bit
# 3       6.0                                      Windows 10/11
# 4       7.0                           Windows 10 (64-bit only)
# ..      ...                                                ...
# 529     6.0                             Windows 7 SP1 or newer
# 530     9.0                               Windows® XP or Vista
# 531     9.0  Windows® XP (32-64 bits) /Windows Vista®(32-64...
# 532     9.0                             Windows 8, 10 (64-bit)
# 533    10.0                                Windows 10 (64 bit)
#
#                                          Min Processor  \
# 0    Intel® Core™ i3-6100 / Core™ i5-2500K or AMD R...
# 1    Intel i5-6600 (3.30GHz) OR AMD Ryzen 2400G (3....
# 2                           Ryzen 5 2600, Core i5-8600
# 3            Intel® Core™ i5-8400 or AMD Ryzen™ 5 2600
# 4                              Intel i3 or AMD Ryzen 3
# ..                                                 ...
# 529   Intel CPU Core 2 Duo (2.9 Ghz) or AMD Equivalent
# 530  2.0 Ghz Intel Pentium IV or equivalent or AMD ...
# 531  Intel Core® 2 Duo 1.8 GHZ or AMD Athlon X2 64 ...
# 532                              from 2.6 GHz, 4 cores
# 533                                                NaN
#
#                                           Min Graphics  Min Graphics NVIDIA  \
# 0    NVIDIA® GeForce® GTX 960 or AMD Radeon™ RX 470...      GeForce GTX 960
# 1          NVIDIA GeForce GTX 970 OR AMD Radeon RX 570      GeForce GTX 970
# 2                                  RX 570, GTX 1050 Ti  GeForce GTX 1050 Ti
# 3      NVIDIA® GeForce® GTX 1060 or AMD Radeon™ RX 580     GeForce GTX 1060
# 4                  NVIDIA GeForce GTX 460 / AMD HD6850      GeForce GTX 460
# ..                                                 ...                  ...
# 529                             NVIDIA Geforce 8500 GT                  NaN
# 530  DirectX 9.0c compatible 64MB video card with P...                  NaN
# 531  256 MB DirectX®  9.0–compliant card with Shade...                  NaN
# 532  NVIDIA GeForce GTX 1050 Ti or AMD Radeon RX 55...  GeForce GTX 1050 Ti
# 533              2GB VRAM GeForce GTX 1030, AMD RX 550     GeForce GTX 1030
#
#     Min Graphics AMD                                         Min Memory  \
# 0             RX 470                                           8 GB RAM
# 1      Radeon RX 570                                           8 GB RAM
# 2             RX 570                                           8 GB RAM
# 3             RX 580                                           8 GB RAM
# 4                NaN                                           8 GB RAM
# ..               ...                                                ...
# 529              NaN                                           2 GB RAM
# 530              NaN                                         512 MB RAM
# 531              NaN  1.5 GB  Windows® XP / 2 GB Windows Vista® - Wi...
# 532    Radeon RX 550                                           4 GB RAM
# 533           RX 550                                           8 GB RAM
#
#                 Min Storage  \
# 0    125 GB available space
# 1     50 GB available space
# 2     50 GB available space
# 3     75 GB available space
# 4     50 GB available space
# ..                      ...
# 529    3 GB available space
# 530    1 GB available space
# 531                     NaN
# 532   30 GB available space
# 533   15 GB available space
#
#                                                 Rec OS  \
# 0    Windows® 10 64 Bit (latest update) or Windows®...
# 1            Windows 10 (64 bit) / Windows 11 (64 bit)
# 2                                    Windows 10 64-bit
# 3                                        Windows 10/11
# 4                             Windows 10 (64-bit only)
# ..                                                 ...
# 529                                         Windows 10
# 530                               Windows® XP or Vista
# 531  Windows® XP (32-64 bits) /Windows Vista®(32-64...
# 532                             Windows 8, 10 (64-bit)
# 533                                Windows 10 (64 bit)
#
#                                          Rec Processor  \
# 0    Intel® Core™ i5-6600K / Core™ i7-4770 or AMD R...
# 1    Intel i7-9700K (3.70GHz) OR AMD Ryzen 5 3600 (...
# 2                           Ryzen 5 3600, Core i7-8700
# 3            Intel® Core™ i7-8700 or AMD Ryzen™ 5 3600
# 4                              Intel i5 or AMD Ryzen 5
# ..                                                 ...
# 529                    Intel Core i5 or AMD Equivalent
# 530             3.0 Ghz Intel Pentium IV or equivalent
# 531  Intel Core® 2 Duo E6700 2.6 GHz or AMD Athlon ...
# 532                              from 3,6 GHz, 6 cores
# 533                                                NaN
#
#                                           Rec Graphics  \
# 0    NVIDIA® GeForce® GTX 1060 or AMD Radeon™ RX 58...
# 1    NVIDIA GeForce RTX 3060 / RTX 2060 OR AMD Rade...
# 2          Radeon RX5700 (8GB), GeForce RTX 2070 (8GB)
# 3     NVIDIA® GeForce® GTX 1070 or AMD Radeon™ RX 5700
# 4                              NVIDIA GeForce GTX 1050
# ..                                                 ...
# 529                             NVIDIA Geforce GTX 960
# 530        256 MB NVIDIA GeForce 6800 series or better
# 531   GeForce 8800 GT or ATI Radeon HD 4700  or better
# 532  NVIDIA GeForce RTX 2060 SUPER or AMD Radeon RX...
# 533          8GB VRAM GeForce RTX 2080, AMD Radeon VII
#
#         Rec Graphics NVIDIA   Rec Graphics AMD  \
# 0          GeForce GTX 1060             RX 580
# 1          GeForce RTX 3060  Radeon RX 5700 XT
# 2          GeForce RTX 2070      Radeon RX5700
# 3          GeForce GTX 1070            RX 5700
# 4          GeForce GTX 1050                NaN
# ..                      ...                ...
# 529         GeForce GTX 960                NaN
# 530                     NaN                NaN
# 531                     NaN                NaN
# 532  GeForce RTX 2060 SUPER     Radeon RX 5700
# 533        GeForce RTX 2080                NaN
#
#                                             Rec Memory             Rec Storage
# 0                                            12 GB RAM  125 GB available space
# 1                                            16 GB RAM   50 GB available space
# 2                                            16 GB RAM   50 GB available space
# 3                                            16 GB RAM   75 GB available space
# 4                                            16 GB RAM   50 GB available space
# ..                                                 ...                     ...
# 529                                           4 GB RAM    3 GB available space
# 530                                           1 GB RAM                     NaN
# 531  1.5 GB  Windows® XP / 2 GB Windows Vista® - Wi...                     NaN
# 532                                          16 GB RAM   30 GB available space
# 533                                          16 GB RAM   15 GB available space
#
# [534 rows x 19 columns]

# %%
games.describe(include="all")
# Out:
#                                      Name Release date Genre 1    Genre 2  \
# count                                 534          532     533        439
# unique                                534          400      11         11
# top     Call of Duty®: Modern Warfare® II  1 Dec, 2022  Action  Adventure
# freq                                    1            9     275        144
# mean                                  NaN          NaN     NaN        NaN
# std                                   NaN          NaN     NaN        NaN
# min                                   NaN          NaN     NaN        NaN
# 25%                                   NaN          NaN     NaN        NaN
# 50%                                   NaN          NaN     NaN        NaN
# 75%                                   NaN          NaN     NaN        NaN
# max                                   NaN          NaN     NaN        NaN
#
#             Rating      Min OS          Min Processor  \
# count   527.000000         530                    515
# unique         NaN         270                    408
# top            NaN  Windows 10  Dual core CPU 2.4 GHz
# freq           NaN          47                     14
# mean      8.258065         NaN                    NaN
# std       1.491996         NaN                    NaN
# min       0.000000         NaN                    NaN
# 25%       7.000000         NaN                    NaN
# 50%       9.000000         NaN                    NaN
# 75%       9.000000         NaN                    NaN
# max      10.000000         NaN                    NaN
#
#                                  Min Graphics Min Graphics NVIDIA  \
# count                                     500                 310
# unique                                    416                  37
# top     GeForce GTS 450-class (Intel HD 4000)     GeForce GTX 660
# freq                                       14                  49
# mean                                      NaN                 NaN
# std                                       NaN                 NaN
# min                                       NaN                 NaN
# 25%                                       NaN                 NaN
# 50%                                       NaN                 NaN
# 75%                                       NaN                 NaN
# max                                       NaN                 NaN
#
#        Min Graphics AMD Min Memory            Min Storage      Rec OS  \
# count                89        524                    481         483
# unique               26         26                     80         222
# top              RX 470   8 GB RAM  50 GB available space  Windows 10
# freq                 10        232                     31          78
# mean                NaN        NaN                    NaN         NaN
# std                 NaN        NaN                    NaN         NaN
# min                 NaN        NaN                    NaN         NaN
# 25%                 NaN        NaN                    NaN         NaN
# 50%                 NaN        NaN                    NaN         NaN
# 75%                 NaN        NaN                    NaN         NaN
# max                 NaN        NaN                    NaN         NaN
#
#                 Rec Processor                  Rec Graphics  \
# count                     475                           461
# unique                    375                           371
# top     Quad core CPU 3.0 GHz  GeForce GTX 760-class (2 GB)
# freq                       14                            14
# mean                      NaN                           NaN
# std                       NaN                           NaN
# min                       NaN                           NaN
# 25%                       NaN                           NaN
# 50%                       NaN                           NaN
# 75%                       NaN                           NaN
# max                       NaN                           NaN
#
#        Rec Graphics NVIDIA Rec Graphics AMD Rec Memory            Rec Storage
# count                  374              181        484                    435
# unique                  45               41         26                     78
# top       GeForce GTX 1060    Radeon RX 580   8 GB RAM  50 GB available space
# freq                    85               35        184                     31
# mean                   NaN              NaN        NaN                    NaN
# std                    NaN              NaN        NaN                    NaN
# min                    NaN              NaN        NaN                    NaN
# 25%                    NaN              NaN        NaN                    NaN
# 50%                    NaN              NaN        NaN                    NaN
# 75%                    NaN              NaN        NaN                    NaN
# max                    NaN              NaN        NaN                    NaN

# %%
games[games["Rating"] == 10]
# Out:
#                                           Name  Release date     Genre 1  \
# 12                      Euro Truck Simulator 2  18 Oct, 2012       Indie
# 25   Cosmoteer: Starship Architect & Commander  24 Oct, 2022  Simulation
# 33                    American Truck Simulator   2 Feb, 2016       Indie
# 54                                     Valheim   2 Feb, 2021      Action
# 62                                  The Forest  30 Apr, 2018      Action
# ..                                         ...           ...         ...
# 486                            Sonic Frontiers   7 Nov, 2022      Action
# 511                                   PlateUp!   4 Aug, 2022      Action
# 514                              Lost Judgment  14 Sep, 2022      Action
# 526   Fireworks Mania - An Explosive Simulator  17 Dec, 2020      Action
# 533                 Bendy and the Dark Revival  15 Nov, 2022      Action
#
#         Genre 2  Rating                                             Min OS  \
# 12   Simulation    10.0                                          Windows 7
# 25     Strategy    10.0  32-bit or 64-bit Microsoft Windows 7 (Service ...
# 33   Simulation    10.0                                   Windows 7 64-bit
# 54    Adventure    10.0                                 Windows 7 or later
# 62    Adventure    10.0                                          Windows 7
# ..          ...     ...                                                ...
# 486   Adventure    10.0                                         Windows 10
# 511      Casual    10.0                                                NaN
# 514   Adventure    10.0                                         Windows 10
# 526      Casual    10.0                                 Windows 7 (64 bit)
# 533   Adventure    10.0                                Windows 10 (64 bit)
#
#                                          Min Processor  \
# 12                               Dual core CPU 2.4 GHz
# 25         Dual-core Intel 2.0 GHz (or AMD equivalent)
# 33                               Dual core CPU 2.4 GHz
# 54                        2.6 GHz Quad Core or similar
# 62                             Intel Dual-Core 2.4 GHz
# ..                                                 ...
# 486             Intel Core i5-3470 or AMD Ryzen 5 1400
# 511                     Quad Core I5 or AMD equivalent
# 514  Intel Core i5-3470, 3.2 GHz or AMD Ryzen 3 120...
# 526                                           i5-2550k
# 533                                                NaN
#
#                                           Min Graphics Min Graphics NVIDIA  \
# 12               GeForce GTS 450-class (Intel HD 4000)                 NaN
# 25               1GB DirectX 9 Graphics Card or better                 NaN
# 33               GeForce GTS 450-class (Intel HD 4000)                 NaN
# 54                   GeForce GTX 950 or Radeon HD 7970     GeForce GTX 950
# 62                               NVIDIA GeForce 8800GT                 NaN
# ..                                                 ...                 ...
# 486  NVIDIA GeForce GTX 660, 2 GB or AMD Radeon HD ...     GeForce GTX 660
# 511            Intel HD Graphics 530 or AMD equivalent                 NaN
# 514  NVIDIA GeForce GTX 960, 2 GB or AMD Radeon RX ...     GeForce GTX 960
# 526                                     Nvidia GTX 770     GeForce GTX 770
# 533              2GB VRAM GeForce GTX 1030, AMD RX 550    GeForce GTX 1030
#
#     Min Graphics AMD Min Memory            Min Storage  \
# 12               NaN   4 GB RAM                    NaN
# 25               NaN   4 GB RAM   2 GB available space
# 33               NaN   4 GB RAM   7 GB available space
# 54               NaN   8 GB RAM   1 GB available space
# 62               NaN   4 GB RAM   5 GB available space
# ..               ...        ...                    ...
# 486              NaN   8 GB RAM  30 GB available space
# 511              NaN   8 GB RAM   2 GB available space
# 514    Radeon RX 460   8 GB RAM  60 GB available space
# 526              NaN   4 GB RAM   2 GB available space
# 533           RX 550   8 GB RAM  15 GB available space
#
#                                                 Rec OS  \
# 12                             Windows 7/8.1/10 64-bit
# 25   64-bit Microsoft Windows 7 (Service Pack 1 req...
# 33                             Windows 7/8.1/10 64-bit
# 54                                  Windows 7 or later
# 62                                           Windows 7
# ..                                                 ...
# 486                                         Windows 10
# 511                                                NaN
# 514                                         Windows 10
# 526                                Windows 10 (64 bit)
# 533                                Windows 10 (64 bit)
#
#                                          Rec Processor  \
# 12                               Quad core CPU 3.0 GHz
# 25   Quad-core Intel 2.5 GHz (or AMD equivalent) or...
# 33                               Quad core CPU 3.0 GHz
# 54                             i5 3GHz or Ryzen 5 3GHz
# 62                                 Quad Core Processor
# ..                                                 ...
# 486             Intel Core i5-6600 or AMD Ryzen 5 2600
# 511                             Quad Core I5 / Ryzen 5
# 514  Intel Core i7-4790, 3.6 GHz or AMD Ryzen 5 160...
# 526                                           I5-4690k
# 533                                                NaN
#
#                                           Rec Graphics Rec Graphics NVIDIA  \
# 12                        GeForce GTX 760-class (2 GB)     GeForce GTX 760
# 25              2GB DirectX 11 Graphics Card or better                 NaN
# 33                        GeForce GTX 760-class (2 GB)     GeForce GTX 760
# 54                   GeForce GTX 1060 or Radeon RX 580    GeForce GTX 1060
# 62                              NVIDIA GeForce GTX 560     GeForce GTX 560
# ..                                                 ...                 ...
# 486  NVIDIA GeForce GTX 1070, 8 GB or AMD Radeon RX...    GeForce GTX 1070
# 511                          GTX 960 or AMD equivalent     GeForce GTX 960
# 514  NVIDIA GeForce RTX 2060, 6 GB or AMD Radeon RX...    GeForce RTX 2060
# 526                                     Nvidia GTX 970     GeForce GTX 970
# 533          8GB VRAM GeForce RTX 2080, AMD Radeon VII    GeForce RTX 2080
#
#     Rec Graphics AMD Rec Memory            Rec Storage
# 12               NaN   6 GB RAM                    NaN
# 25               NaN   8 GB RAM   2 GB available space
# 33               NaN   6 GB RAM   7 GB available space
# 54     Radeon RX 580  16 GB RAM   1 GB available space
# 62               NaN   4 GB RAM   5 GB available space
# ..               ...        ...                    ...
# 486        Radeon RX  12 GB RAM  30 GB available space
# 511              NaN  16 GB RAM   2 GB available space
# 514        Radeon RX   8 GB RAM  80 GB available space
# 526              NaN   8 GB RAM   4 GB available space
# 533              NaN  16 GB RAM  15 GB available space
#
# [66 rows x 19 columns]

# %%
games["Rating"].hist(bins=5)
# Out:
# <AxesSubplot:>

# %%
titlesPerGenre1 = games.groupby(by="Genre 1").count()["Name"]
titlesPerGenre2 = games.groupby(by="Genre 2").count()["Name"]

genres = pd.DataFrame(index=["Genre 1", "Genre 2"], data=[titlesPerGenre1, titlesPerGenre2])

X = np.arange(len(genres.columns))
plt.xticks(ticks=X, labels=genres.columns, rotation=90)
plt.grid()
plt.bar(X-0.21, genres.loc["Genre 1"], width=.4)
plt.bar(X+0.21, genres.loc["Genre 2"], color="orange", width=.4)
plt.legend(["Genre 1", "Genre 2"])

# %%
ratingsAvgPerGenre1 = games.groupby(by="Genre 1").mean()["Rating"]
ratingsAvgPerGenre2 = games.groupby(by="Genre 2").mean()["Rating"]

genreRatings = pd.DataFrame(index=["Genre 1", "Genre 2"], data=[ratingsAvgPerGenre1, ratingsAvgPerGenre2])

X = np.arange(len(genres.columns))
plt.xticks(ticks=X, labels=genres.columns, rotation=90)
plt.grid()
plt.bar(X-0.21, genreRatings.loc["Genre 1"], width=.4)
plt.bar(X+0.21, genreRatings.loc["Genre 2"], color="orange", width=.4)
plt.legend(["Genre 1", "Genre 2"])

genreRatings
# Out:
#            Action  Adventure    Casual  Free to Play     Indie  \
# Genre 1  8.192593   8.716667  8.225806           8.0  8.816327
# Genre 2       NaN   8.100000  8.629630           7.6  9.030769
#
#          Massively Multiplayer       RPG    Racing  Simulation  Strategy  \
# Genre 1               8.600000  7.647059  8.777778    7.566038  8.666667
# Genre 2               6.666667  8.695652  8.666667    8.465753  7.733333
#
#          Utilities  Early Access  Sports
# Genre 1        7.0           NaN     NaN
# Genre 2        NaN      8.444444     7.0

# %%
performances = pd.read_csv("F:\\Projekte\\DataScience\\SteamScraping\\NvidiaGPUs.csv")
performances = performances.set_index("Card")
performances
# Out:
#                      Performance
# Card
# GeForce RTX 3090 Ti    10.000000
# GeForce RTX 4090       10.000000
# GeForce RTX 3090        9.580205
# GeForce RTX 4080 Ti     9.342569
# GeForce RTX 3080 Ti     9.191126
# ...                          ...
# GeForce GTX 675MX       1.050128
# GeForce MX150           1.038448
# GeForce GTX 460         1.030904
# GeForce GTX 745         1.007544
# GeForce GTX 1050        1.000000
#
# [171 rows x 1 columns]

# %%
gamesAndPerformances = games.join(performances, on="Rec Graphics NVIDIA")

# %%
gamesAndPerformances["Performance"].hist()
# Out:
# <AxesSubplot:>
